# %%
import os
import music21 as m21
# Out:
# The kernel failed to start as 'ASTText' could not be imported from 'c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\asttokens\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
import tensorflow
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\ML-Innovative\pre_process.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/d%3A/ML-Innovative/pre_process.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import tensorflow
# ----> <a href='vscode-notebook-cell:/d%3A/ML-Innovative/pre_process.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import keras
#
# File c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# File c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# File c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\functional.py:23
#      20 import itertools
#      21 import warnings
# ---> 23 import tensorflow.compat.v2 as tf
#      25 from keras.src import backend
#      26 from keras.src.dtensor import layout_map as layout_map_lib
#
# ModuleNotFoundError: No module named 'tensorflow.compat'

# %%
from music21 import *

KERN_DATASET_PATH = "essen/europa/deutschl/test/"
ACCEPTABLE_DURATIONS = [
    0.25,
    0.5,
    0.75,
    1,
    1.5,
    2,
    3,
    4
] 

def load_songs_in_kern(dataset_path):
    songs = []
    for path, subdir, files in os.walk(dataset_path):
        for file in files:
            if file[-3:] == "krn":
                song = m21.converter.parse(os.path.join(path, file))
                songs.append(song)

    return songs


def has_Acceptable_duration(song, acceptable_duration):
    for note in song.flat.notesAndRests:
        if note.duration.quarterLength not in acceptable_duration:
            return False
    return True
        

def preprocess(dataset_path):
    pass

    #load folk songs
    print("Loading songs")
    songs = load_songs_in_kern(dataset_path)
    print(f"Loaded {len(songs)} songs.")

    for song in songs:

        #filter songs that have non-acceptable durations
        if not has_Acceptable_duration(song,ACCEPTABLE_DURATIONS):
            continue
        #transwpose songs to Cmaj/Amin

    #encode songs with music time sereies represntation

    #save songs to text file


if __name__ == "__main__":
    songs = load_songs_in_kern(KERN_DATASET_PATH)
    print(f"Loaded {len(songs)} songs.")
    song = songs[0]

    print(f"Has acceptable duration? {has_Acceptable_duration(song,ACCEPTABLE_DURATIONS)}")
    song.show()
# Out:
# The kernel failed to start as 'ASTText' could not be imported from 'c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\asttokens\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
us = environment.UserSettings()
us['musicxmlPath'] = 'C:\\Program Files\\MuseScore 3\\bin\\MuseScore3.exe'
us['musescoreDirectPNGPath'] = 'C:\\Program Files\\MuseScore 3\\bin\\MuseScore3.exe'
us['musicxmlPath']
# Out:
# The kernel failed to start as 'ASTText' could not be imported from 'c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\asttokens\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
from music21 import *
configure.run()
s = corpus.parse('bach/bwv65.2.xml')
s.show()
# Out:
# The kernel failed to start as 'ASTText' could not be imported from 'c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\asttokens\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
# Import Music21
from music21 import *

us = environment.UserSettings()

for k in sorted(us.keys()):
    print(k)

us['musicxmlPath'] = 'C:\\Program Files\\MuseScore 3\\bin\\MuseScore3.exe'
us['localCorpusPath'] = '~/Documents'
print(us['musicxmlPath'])
# Out:
# The kernel failed to start as 'ASTText' could not be imported from 'c:\Users\VIVEK\AppData\Local\Programs\Python\Python310\lib\site-packages\asttokens\__init__.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
